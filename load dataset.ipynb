# %%
# pip install datasets
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/527.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/527.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/527.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/527.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/527.0 kB ? eta -:--:--
#    ------------------- -------------------- 262.1/527.0 kB ? eta -:--:--
#    ------------------- -------------------- 262.1/527.0 kB ? eta -:--:--
#    ------------------- -------------------- 262.1/527.0 kB ? eta -:--:--
#    ------------------- -------------------- 262.1/527.0 kB ? eta -:--:--
#    ------------------- -------------------- 262.1/527.0 kB ? eta -:--:--
#    ------------------- -------------------- 262.1/527.0 kB ? eta -:--:--
#    ------------------- -------------------- 262.1/527.0 kB ? eta -:--:--
# ...

# %%
from datasets import load_dataset

# Login using e.g. `huggingface-cli login` to access this dataset
ds = load_dataset("Parveshiiii/AI-vs-Real")
# Out:
# README.md: 0.00B [00:00, ?B/s]
# C:\Users\Asus Vivobook\AppData\Roaming\Python\Python313\site-packages\huggingface_hub\file_download.py:129: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Asus Vivobook\.cache\huggingface\hub\datasets--Parveshiiii--AI-vs-Real. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# ...

# %%
from datasets import load_dataset

# This will bypass the "receipt check" and let you use the 13,999 rows
ds = load_dataset("Parveshiiii/AI-vs-Real", verification_mode="no_checks")

# Verify it loaded correctly
print(ds)
# Out:
# Generating train split:   0%|          | 0/9999 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['image', 'binary_label'],
#         num_rows: 13999
#     })
# })

# %%
import numpy as np
from datasets import load_dataset

# 1. Load the dataset
ds = load_dataset("Parveshiiii/AI-vs-Real", verification_mode="no_checks")

# 2. Grab a single example
example = ds['train'][0]

# 3. Convert to NumPy (This is the "magic" step)
image_np = np.array(example['image'])

# Now it works with your existing code:
print(image_np.shape) # Result: (Height, Width, Channels)
# Out:
# (426, 640, 3)
